# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
FILENAME = 'dropout_checkpoint_15_9_scores.txt'

with open(FILENAME, 'r') as f:
    scores = list(map(int, f.readlines()))
    
avg_score = []
for i in range(len(scores) - 100):
    avg_score += [np.mean(scores[i:i+100])]

# %%
plt.plot(avg_score)
